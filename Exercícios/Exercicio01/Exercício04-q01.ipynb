# %%
import html5lib
from bs4 import BeautifulSoup as bs
import requests
import re
import time


def download(url, num_retries=10):
    print('Dowloading:', url)
    page = None

    try:
        response = requests.get(url)
        page = response.text
        if response.status_code >= 400:
            print('Download error:', response.text)
            time.sleep(30)
            print("Tenta de novo: " +str(num_retries))
            if num_retries != 0:
                return download(url, num_retries -1)
    except requests.exceptions.RequestException as e:
        print('Download error:', e)
    return page



def busca_links(url_base,url, array_links):
    html = download(url)
    soup = bs(html, 'html5lib')
    lines = soup.find_all("tr")
    
    link = []
    links = []
    for pais in lines:
        links = links + pais.find_all("a", href=True)
    for l in links:
        link.append(l['href'])
        print(l['href'])
    
    array_links = array_links + link
    prox_botao = soup.find("div", id="pagination")
    prev_prox = prox_botao.find_all("a", href=True)
    for n in prev_prox:
        if "Next" in n.text:
            next_url = n["href"]
            return busca_links(url_base,url_base+next_url,array_links)
    return array_links


def busca_dados(url):
    html = download(url)
    soup = bs(html, 'html5lib')

    tr_nome = soup.find("tr", id="places_country__row")
    nome_p = tr_nome.find("td", class_="w2p_fw").text

    tr_area = soup.find("tr", id="places_area__row")
    area = tr_area.find("td", class_="w2p_fw").text
    area = re.sub(r'[^\d]','',area)
    area = float(area)

    tr_populacao = soup.find("tr", id="places_population__row")
    populacao = tr_populacao.find("td", class_="w2p_fw").text
    populacao = populacao.replace(',','')
    populacao = float(populacao)

    densidade = 0
    if area > 0:
        densidade = populacao/area
    
    res = """
    País: {}
    Área: {}
    Pop:  {}
    Dens: {}
    """.format(nome_p, area, populacao, densidade)
    print(res)
    # return {"Nome":nome_p,"densidade":densidade}


# Chamando as funções definidas anteriormente
def main():
    url = 'http://example.webscraping.com'
    links = busca_links(url, url, [])
    tudo = []
    for link in links:
        tudo.append(busca_dados(url + link))
    print(tudo)

# Executando o programa
if __name__=='__main__':
    main()
# Out:
# Dowloading: http://example.webscraping.com
# /places/default/view/Afghanistan-1
# /places/default/view/Aland-Islands-2
# /places/default/view/Albania-3
# /places/default/view/Algeria-4
# /places/default/view/American-Samoa-5
# /places/default/view/Andorra-6
# /places/default/view/Angola-7
# /places/default/view/Anguilla-8
# /places/default/view/Antarctica-9
# /places/default/view/Antigua-and-Barbuda-10
# Dowloading: http://example.webscraping.com/places/default/index/1
# /places/default/view/Argentina-11
# /places/default/view/Armenia-12
# /places/default/view/Aruba-13
# /places/default/view/Australia-14
# /places/default/view/Austria-15
# /places/default/view/Azerbaijan-16
# /places/default/view/Bahamas-17
# /places/default/view/Bahrain-18
# /places/default/view/Bangladesh-19
# /places/default/view/Barbados-20
# Dowloading: http://example.webscraping.com/places/default/index/2
# /places/default/view/Belarus-21
# /places/default/view/Belgium-22
# /places/default/view/Belize-23
# /places/default/view/Benin-24
# /places/default/view/Bermuda-25
# /places/default/view/Bhutan-26
# /places/default/view/Bolivia-27
# /places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
# /places/default/view/Bosnia-and-Herzegovina-29
# /places/default/view/Botswana-30
# Dowloading: http://example.webscraping.com/places/default/index/3
# /places/default/view/Bouvet-Island-31
# /places/default/view/Brazil-32
# /places/default/view/British-Indian-Ocean-Territory-33
# /places/default/view/British-Virgin-Islands-34
# /places/default/view/Brunei-35
# /places/default/view/Bulgaria-36
# /places/default/view/Burkina-Faso-37
# /places/default/view/Burundi-38
# /places/default/view/Cambodia-39
# /places/default/view/Cameroon-40
# Dowloading: http://example.webscraping.com/places/default/index/4
# /places/default/view/Canada-41
# /places/default/view/Cape-Verde-42
# /places/default/view/Cayman-Islands-43
# /places/default/view/Central-African-Republic-44
# /places/default/view/Chad-45
# /places/default/view/Chile-46
# /places/default/view/China-47
# /places/default/view/Christmas-Island-48
# /places/default/view/Cocos-Islands-49
# /places/default/view/Colombia-50
# Dowloading: http://example.webscraping.com/places/default/index/5
# /places/default/view/Comoros-51
# /places/default/view/Cook-Islands-52
# /places/default/view/Costa-Rica-53
# /places/default/view/Croatia-54
# /places/default/view/Cuba-55
# /places/default/view/Curacao-56
# /places/default/view/Cyprus-57
# /places/default/view/Czech-Republic-58
# /places/default/view/Democratic-Republic-of-the-Congo-59
# /places/default/view/Denmark-60
# Dowloading: http://example.webscraping.com/places/default/index/6
# /places/default/view/Djibouti-61
# /places/default/view/Dominica-62
# /places/default/view/Dominican-Republic-63
# /places/default/view/East-Timor-64
# /places/default/view/Ecuador-65
# /places/default/view/Egypt-66
# /places/default/view/El-Salvador-67
# /places/default/view/Equatorial-Guinea-68
# /places/default/view/Eritrea-69
# /places/default/view/Estonia-70
# Dowloading: http://example.webscraping.com/places/default/index/7
# /places/default/view/Ethiopia-71
# /places/default/view/Falkland-Islands-72
# /places/default/view/Faroe-Islands-73
# /places/default/view/Fiji-74
# /places/default/view/Finland-75
# /places/default/view/France-76
# /places/default/view/French-Guiana-77
# /places/default/view/French-Polynesia-78
# /places/default/view/French-Southern-Territories-79
# /places/default/view/Gabon-80
# Dowloading: http://example.webscraping.com/places/default/index/8
# /places/default/view/Gambia-81
# /places/default/view/Georgia-82
# /places/default/view/Germany-83
# /places/default/view/Ghana-84
# /places/default/view/Gibraltar-85
# /places/default/view/Greece-86
# /places/default/view/Greenland-87
# /places/default/view/Grenada-88
# /places/default/view/Guadeloupe-89
# /places/default/view/Guam-90
# Dowloading: http://example.webscraping.com/places/default/index/9
# /places/default/view/Guatemala-91
# /places/default/view/Guernsey-92
# /places/default/view/Guinea-93
# /places/default/view/Guinea-Bissau-94
# /places/default/view/Guyana-95
# /places/default/view/Haiti-96
# /places/default/view/Heard-Island-and-McDonald-Islands-97
# /places/default/view/Honduras-98
# /places/default/view/Hong-Kong-99
# /places/default/view/Hungary-100
# Dowloading: http://example.webscraping.com/places/default/index/10
# /places/default/view/Iceland-101
# /places/default/view/India-102
# /places/default/view/Indonesia-103
# /places/default/view/Iran-104
# /places/default/view/Iraq-105
# /places/default/view/Ireland-106
# /places/default/view/Isle-of-Man-107
# /places/default/view/Israel-108
# /places/default/view/Italy-109
# /places/default/view/Ivory-Coast-110
# Dowloading: http://example.webscraping.com/places/default/index/11
# /places/default/view/Jamaica-111
# /places/default/view/Japan-112
# /places/default/view/Jersey-113
# /places/default/view/Jordan-114
# /places/default/view/Kazakhstan-115
# /places/default/view/Kenya-116
# /places/default/view/Kiribati-117
# /places/default/view/Kosovo-118
# /places/default/view/Kuwait-119
# /places/default/view/Kyrgyzstan-120
# Dowloading: http://example.webscraping.com/places/default/index/12
# /places/default/view/Laos-121
# /places/default/view/Latvia-122
# /places/default/view/Lebanon-123
# /places/default/view/Lesotho-124
# /places/default/view/Liberia-125
# /places/default/view/Libya-126
# /places/default/view/Liechtenstein-127
# /places/default/view/Lithuania-128
# /places/default/view/Luxembourg-129
# /places/default/view/Macao-130
# Dowloading: http://example.webscraping.com/places/default/index/13
# /places/default/view/Macedonia-131
# /places/default/view/Madagascar-132
# /places/default/view/Malawi-133
# /places/default/view/Malaysia-134
# /places/default/view/Maldives-135
# /places/default/view/Mali-136
# /places/default/view/Malta-137
# /places/default/view/Marshall-Islands-138
# /places/default/view/Martinique-139
# /places/default/view/Mauritania-140
# Dowloading: http://example.webscraping.com/places/default/index/14
# /places/default/view/Mauritius-141
# /places/default/view/Mayotte-142
# /places/default/view/Mexico-143
# /places/default/view/Micronesia-144
# /places/default/view/Moldova-145
# /places/default/view/Monaco-146
# /places/default/view/Mongolia-147
# /places/default/view/Montenegro-148
# /places/default/view/Montserrat-149
# /places/default/view/Morocco-150
# Dowloading: http://example.webscraping.com/places/default/index/15
# /places/default/view/Mozambique-151
# /places/default/view/Myanmar-152
# /places/default/view/Namibia-153
# /places/default/view/Nauru-154
# /places/default/view/Nepal-155
# /places/default/view/Netherlands-156
# /places/default/view/Netherlands-Antilles-157
# /places/default/view/New-Caledonia-158
# /places/default/view/New-Zealand-159
# /places/default/view/Nicaragua-160
# Dowloading: http://example.webscraping.com/places/default/index/16
# /places/default/view/Niger-161
# /places/default/view/Nigeria-162
# /places/default/view/Niue-163
# /places/default/view/Norfolk-Island-164
# /places/default/view/North-Korea-165
# /places/default/view/Northern-Mariana-Islands-166
# /places/default/view/Norway-167
# /places/default/view/Oman-168
# /places/default/view/Pakistan-169
# /places/default/view/Palau-170
# Dowloading: http://example.webscraping.com/places/default/index/17
# /places/default/view/Palestinian-Territory-171
# /places/default/view/Panama-172
# /places/default/view/Papua-New-Guinea-173
# /places/default/view/Paraguay-174
# /places/default/view/Peru-175
# /places/default/view/Philippines-176
# /places/default/view/Pitcairn-177
# /places/default/view/Poland-178
# /places/default/view/Portugal-179
# /places/default/view/Puerto-Rico-180
# Dowloading: http://example.webscraping.com/places/default/index/18
# /places/default/view/Qatar-181
# /places/default/view/Republic-of-the-Congo-182
# /places/default/view/Reunion-183
# /places/default/view/Romania-184
# /places/default/view/Russia-185
# /places/default/view/Rwanda-186
# /places/default/view/Saint-Barthelemy-187
# /places/default/view/Saint-Helena-188
# /places/default/view/Saint-Kitts-and-Nevis-189
# /places/default/view/Saint-Lucia-190
# Dowloading: http://example.webscraping.com/places/default/index/19
# /places/default/view/Saint-Martin-191
# /places/default/view/Saint-Pierre-and-Miquelon-192
# /places/default/view/Saint-Vincent-and-the-Grenadines-193
# /places/default/view/Samoa-194
# /places/default/view/San-Marino-195
# /places/default/view/Sao-Tome-and-Principe-196
# /places/default/view/Saudi-Arabia-197
# /places/default/view/Senegal-198
# /places/default/view/Serbia-199
# /places/default/view/Serbia-and-Montenegro-200
# Dowloading: http://example.webscraping.com/places/default/index/20
# /places/default/view/Seychelles-201
# /places/default/view/Sierra-Leone-202
# /places/default/view/Singapore-203
# /places/default/view/Sint-Maarten-204
# /places/default/view/Slovakia-205
# /places/default/view/Slovenia-206
# /places/default/view/Solomon-Islands-207
# /places/default/view/Somalia-208
# /places/default/view/South-Africa-209
# /places/default/view/South-Georgia-and-the-South-Sandwich-Islands-210
# Dowloading: http://example.webscraping.com/places/default/index/21
# /places/default/view/South-Korea-211
# /places/default/view/South-Sudan-212
# /places/default/view/Spain-213
# /places/default/view/Sri-Lanka-214
# /places/default/view/Sudan-215
# /places/default/view/Suriname-216
# /places/default/view/Svalbard-and-Jan-Mayen-217
# /places/default/view/Swaziland-218
# /places/default/view/Sweden-219
# /places/default/view/Switzerland-220
# Dowloading: http://example.webscraping.com/places/default/index/22
# /places/default/view/Syria-221
# /places/default/view/Taiwan-222
# /places/default/view/Tajikistan-223
# /places/default/view/Tanzania-224
# /places/default/view/Thailand-225
# /places/default/view/Togo-226
# /places/default/view/Tokelau-227
# /places/default/view/Tonga-228
# /places/default/view/Trinidad-and-Tobago-229
# /places/default/view/Tunisia-230
# Dowloading: http://example.webscraping.com/places/default/index/23
# /places/default/view/Turkey-231
# /places/default/view/Turkmenistan-232
# /places/default/view/Turks-and-Caicos-Islands-233
# /places/default/view/Tuvalu-234
# /places/default/view/US-Virgin-Islands-235
# /places/default/view/Uganda-236
# /places/default/view/Ukraine-237
# /places/default/view/United-Arab-Emirates-238
# /places/default/view/United-Kingdom-239
# /places/default/view/United-States-240
# Dowloading: http://example.webscraping.com/places/default/index/24
# /places/default/view/United-States-Minor-Outlying-Islands-241
# /places/default/view/Uruguay-242
# /places/default/view/Uzbekistan-243
# /places/default/view/Vanuatu-244
# /places/default/view/Vatican-245
# /places/default/view/Venezuela-246
# /places/default/view/Vietnam-247
# /places/default/view/Wallis-and-Futuna-248
# /places/default/view/Western-Sahara-249
# /places/default/view/Yemen-250
# Dowloading: http://example.webscraping.com/places/default/index/25
# /places/default/view/Zambia-251
# /places/default/view/Zimbabwe-252
# Dowloading: http://example.webscraping.com/places/default/view/Afghanistan-1
#
#     País: Afghanistan
#     Área: 647500.0
#     Pop:  29121286.0
#     Dens: 44.974959073359074
#
# Dowloading: http://example.webscraping.com/places/default/view/Aland-Islands-2
#
#     País: Aland Islands
#     Área: 1580.0
#     Pop:  26711.0
#     Dens: 16.905696202531647
#
# Dowloading: http://example.webscraping.com/places/default/view/Albania-3
#
#     País: Albania
#     Área: 28748.0
#     Pop:  2986952.0
#     Dens: 103.90121051899263
#
# Dowloading: http://example.webscraping.com/places/default/view/Algeria-4
#
#     País: Algeria
#     Área: 2381740.0
#     Pop:  34586184.0
#     Dens: 14.52139360299613
#
# Dowloading: http://example.webscraping.com/places/default/view/American-Samoa-5
#
#     País: American Samoa
#     Área: 199.0
#     Pop:  57881.0
#     Dens: 290.85929648241205
#
# Dowloading: http://example.webscraping.com/places/default/view/Andorra-6
#
#     País: Andorra
#     Área: 468.0
#     Pop:  84000.0
#     Dens: 179.48717948717947
#
# Dowloading: http://example.webscraping.com/places/default/view/Angola-7
#
#     País: Angola
#     Área: 1246700.0
#     Pop:  13068161.0
#     Dens: 10.482201812785755
#
# Dowloading: http://example.webscraping.com/places/default/view/Anguilla-8
#
#     País: Anguilla
#     Área: 102.0
#     Pop:  13254.0
#     Dens: 129.94117647058823
#
# Dowloading: http://example.webscraping.com/places/default/view/Antarctica-9
#
#     País: Antarctica
#     Área: 14000000.0
#     Pop:  0.0
#     Dens: 0.0
#
# Dowloading: http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
#
#     País: Antigua and Barbuda
#     Área: 443.0
#     Pop:  86754.0
#     Dens: 195.83295711060947
#
# Dowloading: http://example.webscraping.com/places/default/view/Argentina-11
#
#     País: Argentina
#     Área: 2766890.0
#     Pop:  41343201.0
#     Dens: 14.942119491559115
#
# Dowloading: http://example.webscraping.com/places/default/view/Armenia-12
#
#     País: Armenia
#     Área: 29800.0
#     Pop:  2968000.0
#     Dens: 99.59731543624162
#
# Dowloading: http://example.webscraping.com/places/default/view/Aruba-13
#
#     País: Aruba
#     Área: 193.0
#     Pop:  71566.0
#     Dens: 370.80829015544043
#
# Dowloading: http://example.webscraping.com/places/default/view/Australia-14
#
#     País: Australia
#     Área: 7686850.0
#     Pop:  21515754.0
#     Dens: 2.799033934576582
#
# Dowloading: http://example.webscraping.com/places/default/view/Austria-15
#
#     País: Austria
#     Área: 83858.0
#     Pop:  8205000.0
#     Dens: 97.84397433757066
#
# Dowloading: http://example.webscraping.com/places/default/view/Azerbaijan-16
#
#     País: Azerbaijan
#     Área: 86600.0
#     Pop:  8303512.0
#     Dens: 95.8835103926097
#
# Dowloading: http://example.webscraping.com/places/default/view/Bahamas-17
#
#     País: Bahamas
#     Área: 13940.0
#     Pop:  301790.0
#     Dens: 21.649210903873744
#
# Dowloading: http://example.webscraping.com/places/default/view/Bahrain-18
#
#     País: Bahrain
#     Área: 665.0
#     Pop:  738004.0
#     Dens: 1109.7804511278196
#
# Dowloading: http://example.webscraping.com/places/default/view/Bangladesh-19
#
#     País: Bangladesh
#     Área: 144000.0
#     Pop:  156118464.0
#     Dens: 1084.156
#
# Dowloading: http://example.webscraping.com/places/default/view/Barbados-20
#
#     País: Barbados
#     Área: 431.0
#     Pop:  285653.0
#     Dens: 662.7679814385151
#
# Dowloading: http://example.webscraping.com/places/default/view/Belarus-21
#
#     País: Belarus
#     Área: 207600.0
#     Pop:  9685000.0
#     Dens: 46.652215799614645
#
# Dowloading: http://example.webscraping.com/places/default/view/Belgium-22
#
#     País: Belgium
#     Área: 30510.0
#     Pop:  10403000.0
#     Dens: 340.97017371353655
#
# Dowloading: http://example.webscraping.com/places/default/view/Belize-23
#
#     País: Belize
#     Área: 22966.0
#     Pop:  314522.0
#     Dens: 13.695114517112254
#
# Dowloading: http://example.webscraping.com/places/default/view/Benin-24
#
#     País: Benin
#     Área: 112620.0
#     Pop:  9056010.0
#     Dens: 80.41209376664891
#
# Dowloading: http://example.webscraping.com/places/default/view/Bermuda-25
#
#     País: Bermuda
#     Área: 53.0
#     Pop:  65365.0
#     Dens: 1233.301886792453
#
# Dowloading: http://example.webscraping.com/places/default/view/Bhutan-26
#
#     País: Bhutan
#     Área: 47000.0
#     Pop:  699847.0
#     Dens: 14.89036170212766
#
# Dowloading: http://example.webscraping.com/places/default/view/Bolivia-27
#
#     País: Bolivia
#     Área: 1098580.0
#     Pop:  9947418.0
#     Dens: 9.05479619144714
#
# Dowloading: http://example.webscraping.com/places/default/view/Bonaire-Saint-Eustatius-and-Saba-28
#
#     País: Bonaire, Saint Eustatius and Saba
#     Área: 328.0
#     Pop:  18012.0
#     Dens: 54.91463414634146
#
# Dowloading: http://example.webscraping.com/places/default/view/Bosnia-and-Herzegovina-29
#
#     País: Bosnia and Herzegovina
#     Área: 51129.0
#     Pop:  4590000.0
#     Dens: 89.77292730153142
#
# Dowloading: http://example.webscraping.com/places/default/view/Botswana-30
#
#     País: Botswana
#     Área: 600370.0
#     Pop:  2029307.0
#     Dens: 3.3800939420690574
#
# Dowloading: http://example.webscraping.com/places/default/view/Bouvet-Island-31
#
#     País: Bouvet Island
#     Área: 49.0
#     Pop:  0.0
#     Dens: 0.0
#
# Dowloading: http://example.webscraping.com/places/default/view/Brazil-32
#
#     País: Brazil
#     Área: 8511965.0
#     Pop:  201103330.0
#     Dens: 23.62595828342809
#
# Dowloading: http://example.webscraping.com/places/default/view/British-Indian-Ocean-Territory-33
#
#     País: British Indian Ocean Territory
#     Área: 60.0
#     Pop:  4000.0
#     Dens: 66.66666666666667
#
# Dowloading: http://example.webscraping.com/places/default/view/British-Virgin-Islands-34
#
#     País: British Virgin Islands
#     Área: 153.0
#     Pop:  21730.0
#     Dens: 142.0261437908497
#
# Dowloading: http://example.webscraping.com/places/default/view/Brunei-35
#
#     País: Brunei
#     Área: 5770.0
#     Pop:  395027.0
#     Dens: 68.46221837088389
#
# Dowloading: http://example.webscraping.com/places/default/view/Bulgaria-36
#
#     País: Bulgaria
#     Área: 110910.0
#     Pop:  7148785.0
#     Dens: 64.45572987106664
#
# Dowloading: http://example.webscraping.com/places/default/view/Burkina-Faso-37
#
#     País: Burkina Faso
#     Área: 274200.0
#     Pop:  16241811.0
#     Dens: 59.23344638949672
#
# Dowloading: http://example.webscraping.com/places/default/view/Burundi-38
#
#     País: Burundi
#     Área: 27830.0
#     Pop:  9863117.0
#     Dens: 354.4059288537549
#
# Dowloading: http://example.webscraping.com/places/default/view/Cambodia-39
#
#     País: Cambodia
#     Área: 181040.0
#     Pop:  14453680.0
#     Dens: 79.8369421122404
#
# Dowloading: http://example.webscraping.com/places/default/view/Cameroon-40
#
#     País: Cameroon
#     Área: 475440.0
#     Pop:  19294149.0
#     Dens: 40.58166961130742
#
# Dowloading: http://example.webscraping.com/places/default/view/Canada-41
#     País: Canada
#     Área: 9984670.0
#     Pop:  33679000.0
#     Dens: 3.37307091771686
#
# Dowloading: http://example.webscraping.com/places/default/view/Cape-Verde-42
#
#     País: Cape Verde
#     Área: 4033.0
#     Pop:  508659.0
#     Dens: 126.12422514257376
#
# Dowloading: http://example.webscraping.com/places/default/view/Cayman-Islands-43
#
#     País: Cayman Islands
#     Área: 262.0
#     Pop:  44270.0
#     Dens: 168.96946564885496
#
# Dowloading: http://example.webscraping.com/places/default/view/Central-African-Republic-44
#
#     País: Central African Republic
#     Área: 622984.0
#     Pop:  4844927.0
#     Dens: 7.776968589883528
#
# Dowloading: http://example.webscraping.com/places/default/view/Chad-45
#
#     País: Chad
#     Área: 1284000.0
#     Pop:  10543464.0
#     Dens: 8.211420560747664
#
# Dowloading: http://example.webscraping.com/places/default/view/Chile-46
#
#     País: Chile
#     Área: 756950.0
#     Pop:  16746491.0
#     Dens: 22.12364224849726
#
# Dowloading: http://example.webscraping.com/places/default/view/China-47
#
#     País: China
#     Área: 9596960.0
#     Pop:  1330044000.0
#     Dens: 138.5901368766776
#
# Dowloading: http://example.webscraping.com/places/default/view/Christmas-Island-48
#
#     País: Christmas Island
#     Área: 135.0
#     Pop:  1500.0
#     Dens: 11.11111111111111
#
# Dowloading: http://example.webscraping.com/places/default/view/Cocos-Islands-49
#
#     País: Cocos Islands
#     Área: 14.0
#     Pop:  628.0
#     Dens: 44.857142857142854
#
# Dowloading: http://example.webscraping.com/places/default/view/Colombia-50
#
#     País: Colombia
#     Área: 1138910.0
#     Pop:  44205293.0
#     Dens: 38.81368413658674
#
# Dowloading: http://example.webscraping.com/places/default/view/Comoros-51
#
#     País: Comoros
#     Área: 2170.0
#     Pop:  773407.0
#     Dens: 356.40875576036865
#
# Dowloading: http://example.webscraping.com/places/default/view/Cook-Islands-52
#
#     País: Cook Islands
#     Área: 240.0
#     Pop:  21388.0
#     Dens: 89.11666666666666
#
# Dowloading: http://example.webscraping.com/places/default/view/Costa-Rica-53
#
#     País: Costa Rica
#     Área: 51100.0
#     Pop:  4516220.0
#     Dens: 88.38003913894325
#
# Dowloading: http://example.webscraping.com/places/default/view/Croatia-54
#
#     País: Croatia
#     Área: 56542.0
#     Pop:  4491000.0
#     Dens: 79.42768207704007
#
# Dowloading: http://example.webscraping.com/places/default/view/Cuba-55
#
#     País: Cuba
#     Área: 110860.0
#     Pop:  11423000.0
#     Dens: 103.03987010644056
#
# Dowloading: http://example.webscraping.com/places/default/view/Curacao-56
# Download error: IP temporarily blocked
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5c35b5fa7418> in <module>()
#      90 # Executando o programa
#      91 if __name__=='__main__':
# ---> 92     main()
#
# <ipython-input-10-5c35b5fa7418> in main()
#      85     tudo = []
#      86     for link in links:
# ---> 87         tudo.append(busca_dados(url + link))
#      88     print(tudo)
#      89
#
# <ipython-input-10-5c35b5fa7418> in busca_dados(url)
#      49
#      50 def busca_dados(url):
# ---> 51     html = download(url)
#      52     soup = bs(html, 'html5lib')
#      53
#
# <ipython-input-10-5c35b5fa7418> in download(url, num_retries)
#      15         if response.status_code >= 400:
#      16             print('Download error:', response.text)
# ---> 17             time.sleep(30)
#      18             print("Tenta de novo: " +str(num_retries))
#      19             if num_retries != 0:
#
# KeyboardInterrupt:
